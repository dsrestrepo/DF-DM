# %% [markdown]
# ### Metadata

# %%
# %cd ..
# Out:
# /Users/davidrestrepo/Data Fusion/DF-DM

# %%
from src.Preprocessing.time_series_preprocessing import get_dataset, train_test_split, normalize_train_features, normalize_test_features, series_to_supervised, features_labels_set, reshape_tensor
from src.Preprocessing.time_series_preprocessing import read_static, read_features
from src.Utils.test_lstm import evaluate, plot_predictions, calculate_mean_std

import pandas as pd
import os
import numpy as np
import random
import tensorflow as tf
import torch

def set_all_seeds(seed):
    """
    Set seed for reproducibility in different libraries.
    :param seed: An integer representing the seed value.
    """
    random.seed(seed)  # Python's built-in random module
    np.random.seed(seed)  # Numpy library
    os.environ['PYTHONHASHSEED'] = str(seed)  # Environment variable

    # TensorFlow
    tf.random.set_seed(seed)
    if tf.__version__[0] == '2':
        # For TensorFlow 2.x, additionally set the global random seed
        tf.compat.v1.set_random_seed(seed)

    # PyTorch
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        # If using GPU with PyTorch, set additional seeds
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  # for multi-GPU

# %%
DIR_PATH = 'datasets/violence_prediction/'
file = 'metadata_labels.csv'
cohort = 'cities.csv'

# %%
cities = pd.read_csv(DIR_PATH + cohort)
cities
# Out:
#        lat      lng   Municipality  Municipality code     ISO
# 0   6.2447 -75.5748       Medellín               5001  CO-ANT
# 1   3.4400 -76.5197           Cali              76001  CO-VAC
# 2   4.5781 -74.2144         Soacha              25754  CO-CUN
# 3   4.1425 -73.6294  Villavicencio              50001  CO-MET
# 4   1.2136 -77.2811          Pasto              52001  CO-NAR
# 5  10.9639 -74.7964   Barranquilla               8001  CO-ATL
# 6   7.1186 -73.1161    Bucaramanga              68001  CO-SAN
# 7   4.4378 -75.2006         Ibagué              73001  CO-TOL
# 8   2.4411 -76.6061        Popayán              19001  CO-CAU
# 9   7.9075 -72.5047         Cúcuta              54001  CO-NSA

# %% [markdown]
# ##### Constants

# %%
""" Read Dataset:"""
image_embeddings = 'Embeddings/Embeddings_dinov2_large.csv'
media_data = None # 'datasets/violence_prediction/media_data.csv'
static = 'datasets/violence_prediction/metadata_labels.csv'

DIR_PATH = 'datasets/violence_prediction/'
file = 'metadata_labels.csv'
labels = pd.read_csv(DIR_PATH + file)

# Get list of municipalities:
cohort = 'cities.csv'
cities = pd.read_csv(DIR_PATH + cohort)
Municipalities = cities.Municipality.values

""" Dataset Preprocessing:"""
train_percentage = 80
T = 3
autoregressive = False
feature_range = (-1, 1)

""" Model Parameters:"""
lstm_layers=[1000, 500]
nn_layers=[250, 120, 1]
dense_acivation='relu'
recurrent_cells='LSTM'
bidirectional=False

seed = 1
n_tests = 3

# %% [markdown]
# ### Read and Preprocess the Data

# %% [markdown]
# #### Read the Data

# %%
# Read dataset
dengue_df = [get_dataset(labels_path=labels, embeddings_path=image_embeddings, municipality=Municipality, temp_prec=media_data, static=static) for Municipality in Municipalities]
type(dengue_df)
# Out:
# Obtaining dataframe for the city of Medellín only...
# Obtaining dataframe for the city of Medellín only...
# Obtaining dataframe for the city of Cali only...
# Obtaining dataframe for the city of Cali only...
# Obtaining dataframe for the city of Soacha only...
# Obtaining dataframe for the city of Soacha only...
# Obtaining dataframe for the city of Villavicencio only...
# Obtaining dataframe for the city of Villavicencio only...
# Obtaining dataframe for the city of Pasto only...
# Obtaining dataframe for the city of Pasto only...
# Obtaining dataframe for the city of Barranquilla only...
# Obtaining dataframe for the city of Barranquilla only...
# Obtaining dataframe for the city of Bucaramanga only...
# Obtaining dataframe for the city of Bucaramanga only...
# Obtaining dataframe for the city of Ibagué only...
# Obtaining dataframe for the city of Ibagué only...
# Obtaining dataframe for the city of Popayán only...
# Obtaining dataframe for the city of Popayán only...
# Obtaining dataframe for the city of Cúcuta only...
# Obtaining dataframe for the city of Cúcuta only...
# list

# %% [markdown]
# #### Train-Test Split

# %%
train_df = []
test_df = []

for i in range(len(dengue_df)):
    train_df_aux, test_df_aux = train_test_split(dengue_df[i], train_percentage)
    train_df.append(train_df_aux)
    test_df.append(test_df_aux)
# Out:
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)
# The train shape is: (210, 1051)
# The test shape is: (53, 1051)

# %% [markdown]
# #### Normalize the Data

# %%
# Merge:
train_df = pd.concat(train_df, keys=Municipalities)
test_df = pd.concat(test_df, keys=Municipalities)

# %%
# Scale train:
train_df, scalers = normalize_train_features(train_df, feature_range=feature_range)
train_df = [train_df[train_df.index.get_level_values(0) == municipality] for municipality in Municipalities]

train_df[1].head()
# Out:
#                     0         1         2         3         4         5  \
# Cali 201751 -0.081407  1.083399 -0.196401  0.510929 -0.646225 -0.829237
#      201752 -0.808544 -1.428550 -0.274904 -1.397886 -0.478908 -1.169888
#      201801 -0.251622  0.746630  0.133727  0.379409 -0.183339 -0.964580
#      201802 -0.251622  0.746630  0.133727  0.379409 -0.183339 -0.964580
#      201803 -0.093196 -0.162284 -0.162907  0.350659  0.448797 -0.230058
#
#                     6         7         8         9  ...  \
# Cali 201751 -0.997286  0.264655 -1.605949  1.466506  ...
#      201752 -1.954823 -3.241076  1.438558 -1.409513  ...
#      201801 -0.659794  0.113919 -1.096438  1.001226  ...
#      201802 -0.659794  0.113919 -1.096438  1.001226  ...
#      201803  0.701896  1.204476 -1.547080  0.592271  ...
#
#              Buildingstratification1(%)  Buildingstratification2(%)  \
# Cali 201751                   -0.703859                   -0.409825
#      201752                   -0.703859                   -0.409825
#      201801                   -0.703859                   -0.409825
#      201802                   -0.703859                   -0.409825
#      201803                   -0.703859                   -0.409825
#
#              Buildingstratification3(%)  Buildingstratification4(%)  \
# Cali 201751                    0.691928                    0.172051
#      201752                    0.691928                    0.172051
#      201801                    0.691928                    0.172051
#      201802                    0.691928                    0.172051
#      201803                    0.691928                    0.172051
#
#              Buildingstratification5(%)  Buildingstratification6(%)  \
# Cali 201751                    1.859602                    0.625183
#      201752                    1.859602                    0.625183
#      201801                    1.859602                    0.625183
#      201802                    1.859602                    0.625183
#      201803                    1.859602                    0.625183
#
#              NumberofhospitalsperKm2  NumberofhousesperKm2  population  \
# Cali 201751                 0.096275              0.412343    1.747972
#      201752                 0.096275              0.412343    1.747972
#      201801                 0.096275              0.412343    1.747972
#      201802                 0.096275              0.412343    1.747972
#      201803                 0.096275              0.412343    1.747972
#
#                Labels
# Cali 201751 -0.364738
#      201752 -0.864653
#      201801  0.695082
#      201802  0.175170
#      201803  0.495116
#
# [5 rows x 1051 columns]

# %%
# Scale test:
test_df = normalize_test_features(test_df, scalers=scalers)
test_df = [test_df[test_df.index.get_level_values(0) == municipality] for municipality in Municipalities]

test_df[1].head()
# Out:
#                     0         1         2         3         4         5  \
# Cali 202152  0.404999 -1.280717 -0.314145 -0.080141  0.318612 -1.194646
#      202201  0.598779 -1.391766  1.135571 -1.643763 -0.363679 -1.665622
#      202202 -0.260279  0.488864  0.658107  0.861322 -0.150612  0.055596
#      202203 -0.260279  0.488864  0.658107  0.861322 -0.150612  0.055596
#      202204  0.312698  0.236573  0.091713  0.351006  0.497083 -0.407208
#
#                     6         7         8         9  ...  \
# Cali 202152 -0.653046 -0.078474  0.226728  0.688853  ...
#      202201 -0.674750 -1.707049  0.095966 -2.796665  ...
#      202202 -0.071134  1.054469 -0.466272  0.985397  ...
#      202203 -0.071134  1.054469 -0.466272  0.985397  ...
#      202204  0.551389  1.811359 -0.485746  1.177510  ...
#
#              Buildingstratification1(%)  Buildingstratification2(%)  \
# Cali 202152                   -0.703859                   -0.409825
#      202201                   -0.703859                   -0.409825
#      202202                   -0.703859                   -0.409825
#      202203                   -0.703859                   -0.409825
#      202204                   -0.703859                   -0.409825
#
#              Buildingstratification3(%)  Buildingstratification4(%)  \
# Cali 202152                    0.691928                    0.172051
#      202201                    0.691928                    0.172051
#      202202                    0.691928                    0.172051
#      202203                    0.691928                    0.172051
#      202204                    0.691928                    0.172051
#
#              Buildingstratification5(%)  Buildingstratification6(%)  \
# Cali 202152                    1.859602                    0.625183
#      202201                    1.859602                    0.625183
#      202202                    1.859602                    0.625183
#      202203                    1.859602                    0.625183
#      202204                    1.859602                    0.625183
#
#              NumberofhospitalsperKm2  NumberofhousesperKm2  population  \
# Cali 202152                 0.096275              0.412343    1.747972
#      202201                 0.096275              0.412343    1.747972
#      202202                 0.096275              0.412343    1.747972
#      202203                 0.096275              0.412343    1.747972
#      202204                 0.096275              0.412343    1.747972
#
#                Labels
# Cali 202152  0.495116
#      202201  0.835058
#      202202  0.995031
#      202203  1.654919
#      202204  1.095014
#
# [5 rows x 1051 columns]

# %% [markdown]
# #### Prepare data for time series supervised learning (function to create sliding window)

# %%
# frame as supervised learning
train = [series_to_supervised(df, n_in=T, autoregressive=autoregressive) for df in train_df]
test = [series_to_supervised(df, n_in=T, autoregressive=autoregressive) for df in test_df]

train[1].shape
# Out:
# (208, 3151)

# %% [markdown]
# #### Merge

# %%
# Merge:
train = pd.concat(train, keys=Municipalities)
test = pd.concat(test, keys=Municipalities)

train.shape
# Out:
# (2080, 3151)

# %% [markdown]
# #### Features and Labels Set

# %%
# Train features and labels set
print('Train:')
train_X, train_y, n_features = features_labels_set(timeseries_data=train, original_df=dengue_df[0], autoregressive=autoregressive)

# Test features and labels set
print('Test:')
test_X, test_y, n_features = features_labels_set(timeseries_data=test, original_df=dengue_df[0], autoregressive=autoregressive)
# Out:
# Train:
# The shape of the features is (2080, 3150)
# The shape of the labels is (2080, 1)
# Test:
# The shape of the features is (510, 3150)
# The shape of the labels is (510, 1)

# %%
# reshape input to be 3D [samples, timesteps, features]
if T != 0:
    train_X, test_X = reshape_tensor(train_X, test_X, n_features, T, autoregressive)
# Out:
# The initial shapes are:
# The train shape is (2080, 3150)
# The test shape is (510, 3150)
# -----------------------
# The Final shapes are:
# The train shape is (2080, 3, 1050)
# The test shape is (510, 3, 1050)

# %%
# Use the Function:
if T != 0: 
    sequence=train_X.shape[1]
    features=train_X.shape[2]
else:
    sequence=T
    features=train_X.shape[1]

set_all_seeds(1)
calculate_mean_std(lstm_layers, nn_layers, sequence, features, dense_acivation, recurrent_cells, bidirectional, train_X, train_y, test_X, test_y, scalers['scaler_Labels'], monitor=True, plot=None, epochs=50, batch_size=16, n_tests=n_tests, plot_samples=True, Municipality='Global')
# Out:
# 2024-01-17 00:45:33.025413: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-01-17 00:45:33.025461: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-01-17 00:45:33.025466: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-01-17 00:45:33.025922: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-01-17 00:45:33.025982: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2024-01-17 00:45:36.055188: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:45:36.535747: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:45:36.653127: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:45:37.155221: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:45:37.343706: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:45:45.934144: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:45:46.140895: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:45:46.224680: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Restoring model weights from the end of the best epoch: 3.
# Epoch 11: early stopping
# 2024-01-17 00:47:13.225541: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:47:13.399166: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
#  7/16 [============>.................] - ETA: 0s
# 2024-01-17 00:47:13.482567: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 1s 22ms/step
# Test MAE: 30.209
# Test RMSE: 48.789
# Test sMAPE: 46.519
# Test R Squared: -0.041
# {'mae': 30.209117003048167, 'rmse': 48.788809730272845, 'smape': 46.51859955100812, 'r2': -0.041005485756639315}
# 2024-01-17 00:47:16.872641: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:47:17.344540: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:47:17.415627: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:47:17.865039: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:47:18.039231: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:47:26.567035: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:47:26.766884: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:47:26.844831: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Restoring model weights from the end of the best epoch: 14.
# Epoch 22: early stopping
# 2024-01-17 00:50:49.649515: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:50:50.160141: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:50:50.369610: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 4s 24ms/step
# Test MAE: 29.423
# Test RMSE: 45.092
# Test sMAPE: 45.761
# Test R Squared: 0.111
# {'mae': 29.423183411242913, 'rmse': 45.09240520710654, 'smape': 45.76110258407388, 'r2': 0.11075921373785647}
# 2024-01-17 00:50:58.354267: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:50:59.541646: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:50:59.737051: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:51:02.258614: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:51:02.545456: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:51:12.706120: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:51:12.989047: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:51:13.111109: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Restoring model weights from the end of the best epoch: 8.
# Epoch 16: early stopping
# 2024-01-17 00:53:52.818994: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:53:53.111779: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:53:53.478002: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 3s 26ms/step
# Test MAE: 29.536
# Test RMSE: 45.386
# Test sMAPE: 46.428
# Test R Squared: 0.099
# {'mae': 29.535512572643803, 'rmse': 45.385823934780234, 'smape': 46.428435319781734, 'r2': 0.09914888561839419}
# rmse : average=46.422, std=1.678
# mae : average=29.723, std=0.347
# smape : average=46.236, std=0.338
# r2 : average=0.056, std=0.069
# ([46.42234629071987, 1.6776244207197823],
#  [29.722604328978292, 0.34705945374265035],
#  [46.23604581828791, 0.3378468133562155],
#  [0.05630087119987045, 0.06896905227646753])

# %% [markdown]
# ### Joint Fusion Model

# %%
if T != 0: 
    sequence=train_X.shape[1]
    features=train_X.shape[2]
else:
    sequence=T
    features=train_X.shape[1]

# %%
set_all_seeds(1)

x_ar = train_X[:, :, :1024]
x_ar_test = test_X[:, :, :1024]
train_X = train_X[:, :, 1024:]
test_X = test_X[:, :, 1024:]

calculate_mean_std(lstm_layers, nn_layers, sequence, train_X.shape[2], dense_acivation, recurrent_cells, bidirectional, train_X, train_y, test_X, test_y, scalers['scaler_Labels'], monitor=True, plot=None, epochs=50, batch_size=16, n_tests=n_tests, plot_samples=True, Municipality='Global', fusion='joint', x_ar=x_ar, x_ar_test=x_ar_test)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 3, 1000)           4108000
#
#  lstm_7 (LSTM)               (None, 500)               3002000
#
#  batch_normalization_9 (Bat  (None, 500)               2000
#  chNormalization)
#
#  dense_9 (Dense)             (None, 250)               125250
#
#  batch_normalization_10 (Ba  (None, 250)               1000
#  tchNormalization)
#
#  dense_10 (Dense)            (None, 120)               30120
#
#  batch_normalization_11 (Ba  (None, 120)               480
#  tchNormalization)
#
#  dense_11 (Dense)            (None, 1)                 121
#
# =================================================================
# Total params: 7268971 (27.73 MB)
# Trainable params: 7267231 (27.72 MB)
# Non-trainable params: 1740 (6.80 KB)
# _________________________________________________________________
# None model1 sum
# (None, 14641)
# 2024-01-17 00:54:28.811754: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:30.095417: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:30.118757: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:30.218138: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:30.343494: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:30.488126: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:30.541107: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:30.942056: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:31.059533: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:46.399018: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:47.046303: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:47.047042: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:47.071415: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:47.071797: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:47.289220: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:47.297643: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:47.405172: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:54:47.409840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Restoring model weights from the end of the best epoch: 9.
# Epoch 17: early stopping
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  lstm_6_input (InputLayer)   [(None, 3, 26)]              0         []
#
#  lstm_8_input (InputLayer)   [(None, 3, 1024)]            0         []
#
#  sequential_5 (Sequential)   (None, 120)                  7268850   ['lstm_6_input[0][0]']
#
#  sequential_6 (Sequential)   (None, 120)                  1126085   ['lstm_8_input[0][0]']
#                                                           0
#
#  outer_product_layer (Outer  (None, 14641)                0         ['sequential_5[0][0]',
#  ProductLayer)                                                       'sequential_6[0][0]']
#
#  dense_15 (Dense)            (None, 256)                  3748352   ['outer_product_layer[0][0]']
#
#  dense_16 (Dense)            (None, 128)                  32896     ['dense_15[0][0]']
#
#  sequential_3 (Sequential)   (None, 1)                    7268971   ['lstm_6_input[0][0]']
#
#  sequential_4 (Sequential)   (None, 1)                    1126097   ['lstm_8_input[0][0]']
#                                                           1
#
#  concatenate (Concatenate)   (None, 130)                  0         ['dense_16[0][0]',
#                                                                      'sequential_3[0][0]',
#                                                                      'sequential_4[0][0]']
#
#  dense_17 (Dense)            (None, 64)                   8384      ['concatenate[0][0]']
#
#  dense_18 (Dense)            (None, 32)                   2080      ['dense_17[0][0]']
#
#  dense_19 (Dense)            (None, 16)                   528       ['dense_18[0][0]']
#
#  dense_20 (Dense)            (None, 1)                    17        ['dense_19[0][0]']
#
# ==================================================================================================
# Total params: 22322199 (85.15 MB)
# Trainable params: 3792499 (14.47 MB)
# Non-trainable params: 18529700 (70.69 MB)
# __________________________________________________________________________________________________
# 2024-01-17 00:58:06.391933: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:07.008885: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:07.008918: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:07.031797: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:07.031823: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:07.277282: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:07.290187: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:07.395298: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:07.406710: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 5s 109ms/step
# Test MAE: 27.790
# Test RMSE: 39.452
# Test sMAPE: 57.592
# Test R Squared: 0.319
# {'mae': 27.78977060553563, 'rmse': 39.45209068721753, 'smape': 57.59234466107554, 'r2': 0.31930491065215005}
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 3, 1000)           4108000
#
#  lstm_11 (LSTM)              (None, 500)               3002000
#
#  batch_normalization_15 (Ba  (None, 500)               2000
#  tchNormalization)
#
#  dense_21 (Dense)            (None, 250)               125250
#
#  batch_normalization_16 (Ba  (None, 250)               1000
#  tchNormalization)
#
#  dense_22 (Dense)            (None, 120)               30120
#
#  batch_normalization_17 (Ba  (None, 120)               480
#  tchNormalization)
#
#  dense_23 (Dense)            (None, 1)                 121
#
# =================================================================
# Total params: 7268971 (27.73 MB)
# Trainable params: 7267231 (27.72 MB)
# Non-trainable params: 1740 (6.80 KB)
# _________________________________________________________________
# None model1 sum
# (None, 14641)
# 2024-01-17 00:58:22.607316: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:23.840320: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:23.860805: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:23.942534: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:24.029271: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:24.144587: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:24.190446: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:24.304840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:24.552196: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:34.812315: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:35.387295: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:35.408890: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:35.568686: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:35.608173: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:35.638187: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:35.664580: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:35.807318: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 00:58:35.872080: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Restoring model weights from the end of the best epoch: 9.
# Epoch 17: early stopping
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  lstm_10_input (InputLayer)  [(None, 3, 26)]              0         []
#
#  lstm_12_input (InputLayer)  [(None, 3, 1024)]            0         []
#
#  sequential_9 (Sequential)   (None, 120)                  7268850   ['lstm_10_input[0][0]']
#
#  sequential_10 (Sequential)  (None, 120)                  1126085   ['lstm_12_input[0][0]']
#                                                           0
#
#  outer_product_layer_1 (Out  (None, 14641)                0         ['sequential_9[0][0]',
#  erProductLayer)                                                     'sequential_10[0][0]']
#
#  dense_27 (Dense)            (None, 256)                  3748352   ['outer_product_layer_1[0][0]'
#                                                                     ]
#
#  dense_28 (Dense)            (None, 128)                  32896     ['dense_27[0][0]']
#
#  sequential_7 (Sequential)   (None, 1)                    7268971   ['lstm_10_input[0][0]']
#
#  sequential_8 (Sequential)   (None, 1)                    1126097   ['lstm_12_input[0][0]']
#                                                           1
#
#  concatenate_1 (Concatenate  (None, 130)                  0         ['dense_28[0][0]',
#  )                                                                   'sequential_7[0][0]',
#                                                                      'sequential_8[0][0]']
#
#  dense_29 (Dense)            (None, 64)                   8384      ['concatenate_1[0][0]']
#
#  dense_30 (Dense)            (None, 32)                   2080      ['dense_29[0][0]']
#
#  dense_31 (Dense)            (None, 16)                   528       ['dense_30[0][0]']
#
#  dense_32 (Dense)            (None, 1)                    17        ['dense_31[0][0]']
#
# ==================================================================================================
# Total params: 22322199 (85.15 MB)
# Trainable params: 3792499 (14.47 MB)
# Non-trainable params: 18529700 (70.69 MB)
# __________________________________________________________________________________________________
# 2024-01-17 01:01:16.719887: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:17.319446: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:17.319901: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:17.346636: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:17.346782: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:17.629735: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:17.637689: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:17.718703: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:17.782215: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 5s 94ms/step
# Test MAE: 27.134
# Test RMSE: 39.268
# Test sMAPE: 44.994
# Test R Squared: 0.326
# {'mae': 27.134433140474208, 'rmse': 39.26803675812045, 'smape': 44.99372510435291, 'r2': 0.3256413233203178}
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 3, 1000)           4108000
#
#  lstm_15 (LSTM)              (None, 500)               3002000
#
#  batch_normalization_21 (Ba  (None, 500)               2000
#  tchNormalization)
#
#  dense_33 (Dense)            (None, 250)               125250
#
#  batch_normalization_22 (Ba  (None, 250)               1000
#  tchNormalization)
#
#  dense_34 (Dense)            (None, 120)               30120
#
#  batch_normalization_23 (Ba  (None, 120)               480
#  tchNormalization)
#
#  dense_35 (Dense)            (None, 1)                 121
#
# =================================================================
# Total params: 7268971 (27.73 MB)
# Trainable params: 7267231 (27.72 MB)
# Non-trainable params: 1740 (6.80 KB)
# _________________________________________________________________
# None model1 sum
# (None, 14641)
# 2024-01-17 01:01:40.595181: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:41.957795: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:41.983879: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:42.097207: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:42.240339: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:42.262742: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:42.461865: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:42.470231: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:43.202057: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:57.253631: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:57.921829: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:57.922330: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:57.948768: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:57.948799: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:58.262680: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:58.265585: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:58.281006: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:01:58.283978: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Restoring model weights from the end of the best epoch: 4.
# Epoch 12: early stopping
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  lstm_14_input (InputLayer)  [(None, 3, 26)]              0         []
#
#  lstm_16_input (InputLayer)  [(None, 3, 1024)]            0         []
#
#  sequential_13 (Sequential)  (None, 120)                  7268850   ['lstm_14_input[0][0]']
#
#  sequential_14 (Sequential)  (None, 120)                  1126085   ['lstm_16_input[0][0]']
#                                                           0
#
#  outer_product_layer_2 (Out  (None, 14641)                0         ['sequential_13[0][0]',
#  erProductLayer)                                                     'sequential_14[0][0]']
#
#  dense_39 (Dense)            (None, 256)                  3748352   ['outer_product_layer_2[0][0]'
#                                                                     ]
#
#  dense_40 (Dense)            (None, 128)                  32896     ['dense_39[0][0]']
#
#  sequential_11 (Sequential)  (None, 1)                    7268971   ['lstm_14_input[0][0]']
#
#  sequential_12 (Sequential)  (None, 1)                    1126097   ['lstm_16_input[0][0]']
#                                                           1
#
#  concatenate_2 (Concatenate  (None, 130)                  0         ['dense_40[0][0]',
#  )                                                                   'sequential_11[0][0]',
#                                                                      'sequential_12[0][0]']
#
#  dense_41 (Dense)            (None, 64)                   8384      ['concatenate_2[0][0]']
#
#  dense_42 (Dense)            (None, 32)                   2080      ['dense_41[0][0]']
#
#  dense_43 (Dense)            (None, 16)                   528       ['dense_42[0][0]']
#
#  dense_44 (Dense)            (None, 1)                    17        ['dense_43[0][0]']
#
# ==================================================================================================
# Total params: 22322199 (85.15 MB)
# Trainable params: 3792499 (14.47 MB)
# Non-trainable params: 18529700 (70.69 MB)
# __________________________________________________________________________________________________
# 2024-01-17 01:04:18.101648: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:04:18.877097: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:04:18.891561: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:04:18.927732: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:04:18.928012: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:04:19.235079: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:04:19.275537: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:04:19.410415: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-01-17 01:04:19.415208: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 6s 148ms/step
# Test MAE: 26.479
# Test RMSE: 36.142
# Test sMAPE: 57.570
# Test R Squared: 0.429
# {'mae': 26.479411216343152, 'rmse': 36.142244795054545, 'smape': 57.56993645815648, 'r2': 0.4287281579675024}
# rmse : average=38.287, std=1.519
# mae : average=27.135, std=0.535
# smape : average=53.385, std=5.934
# r2 : average=0.358, std=0.050
# ([38.287457413464175, 1.5187542802884966],
#  [27.13453832078433, 0.534951985701143],
#  [53.385335407861646, 5.933771602522572],
#  [0.3578914639799901, 0.05015586002775533])
