# %% [markdown]
# ### Setup

# %%
import os
import pandas as pd 
from epiweeks import Week

# %%
PATH_CODES = '../../cities.csv'
KEYWORD = 'violencia de genero'

# %% [markdown]
# #### CSV Files

# %%
cities = pd.read_csv(PATH_CODES)
cities
# Out:
#        lat      lng   Municipality  Municipality code     ISO
# 0   6.2447 -75.5748       Medellín               5001  CO-ANT
# 1   3.4400 -76.5197           Cali              76001  CO-VAC
# 2   4.5781 -74.2144         Soacha              25754  CO-CUN
# 3   4.1425 -73.6294  Villavicencio              50001  CO-MET
# 4   1.2136 -77.2811          Pasto              52001  CO-NAR
# 5  10.9639 -74.7964   Barranquilla               8001  CO-ATL
# 6   7.1186 -73.1161    Bucaramanga              68001  CO-SAN
# 7   4.4378 -75.2006         Ibagué              73001  CO-TOL
# 8   2.4411 -76.6061        Popayán              19001  CO-CAU
# 9   7.9075 -72.5047         Cúcuta              54001  CO-NSA

# %% [markdown]
# ### Read each file

# %%
dfs = []
for city in cities.ISO:
    dfs.append(pd.read_csv(f'cities_cohort/{city}_{KEYWORD}.csv'))
    # dfs.append(pd.concat([pd.read_csv(f'cities/{city}_{KEYWORD}(1).csv'), pd.read_csv(f'cities/{city}_{KEYWORD}.csv')]))

# %%
dfs[0]
# Out:
#                     Category: All categories
# Week        violencia de genero: (Antioquia)
# 2017-12-24                                 0
# 2017-12-31                                32
# 2018-01-07                                 0
# 2018-01-14                                22
# ...                                      ...
# 2022-12-04                                41
# 2022-12-11                                 1
# 2022-12-18                                38
# 2022-12-25                                21
# 2023-01-01                                 0
#
# [264 rows x 1 columns]

# %% [markdown]
# ### Merge:

# %%
# Merge the dataframes by the "Week" column
merged_df = pd.concat(dfs, axis=1, keys=cities['Municipality'])

# %%
merged_df
# Out:
# Municipality                          Medellín  \
#                       Category: All categories
# Week          violencia de genero: (Antioquia)
# 2017-12-24                                   0
# 2017-12-31                                  32
# 2018-01-07                                   0
# 2018-01-14                                  22
# ...                                        ...
# 2022-12-04                                  41
# 2022-12-11                                   1
# 2022-12-18                                  38
# 2022-12-25                                  21
# 2023-01-01                                   0
#
# Municipality                                    Cali  \
#                             Category: All categories
# Week          violencia de genero: (Valle del Cauca)
# 2017-12-24                                         0
# 2017-12-31                                         0
# 2018-01-07                                         1
# 2018-01-14                                        13
# ...                                              ...
# 2022-12-04                                        13
# 2022-12-11                                        33
# 2022-12-18                                         0
# 2022-12-25                                        12
# 2023-01-01                                        <1
#
# Municipality                               Soacha  \
#                          Category: All categories
# Week          violencia de genero: (Cundinamarca)
# 2017-12-24                                      0
# 2017-12-31                                     31
# 2018-01-07                                      2
# 2018-01-14                                     25
# ...                                           ...
# 2022-12-04                                      0
# 2022-12-11                                     22
# 2022-12-18                                     22
# 2022-12-25                                     14
# 2023-01-01                                      1
#
# Municipality                Villavicencio                          Pasto  \
#                  Category: All categories       Category: All categories
# Week          violencia de genero: (Meta)  violencia de genero: (Narino)
# 2017-12-24                              1                             30
# 2017-12-31                              0                             88
# 2018-01-07                              0                              0
# 2018-01-14                              0                              1
# ...                                   ...                            ...
# 2022-12-04                             17                             50
# 2022-12-11                              0                              1
# 2022-12-18                             12                              1
# 2022-12-25                             <1                              0
# 2023-01-01                              0                              0
#
# Municipality                      Barranquilla  \
#                       Category: All categories
# Week          violencia de genero: (Atlantico)
# 2017-12-24                                   0
# 2017-12-31                                  37
# 2018-01-07                                   0
# 2018-01-14                                   0
# ...                                        ...
# 2022-12-04                                   0
# 2022-12-11                                  18
# 2022-12-18                                  19
# 2022-12-25                                   0
# 2023-01-01                                  20
#
# Municipality                                  Bucaramanga  \
#                                  Category: All categories
# Week          violencia de genero: (Santander Department)
# 2017-12-24                                             47
# 2017-12-31                                              0
# 2018-01-07                                              0
# 2018-01-14                                             36
# ...                                                   ...
# 2022-12-04                                              0
# 2022-12-11                                             44
# 2022-12-18                                              0
# 2022-12-25                                             19
# 2023-01-01                                              0
#
# Municipality                         Ibagué  \
#                    Category: All categories
# Week          violencia de genero: (Tolima)
# 2017-12-24                                0
# 2017-12-31                                1
# 2018-01-07                                0
# 2018-01-14                                1
# ...                                     ...
# 2022-12-04                               18
# 2022-12-11                               61
# 2022-12-18                               35
# 2022-12-25                               55
# 2023-01-01                               20
#
# Municipality                                  Popayán  \
#                              Category: All categories
# Week          violencia de genero: (Cauca Department)
# 2017-12-24                                          1
# 2017-12-31                                          0
# 2018-01-07                                          3
# 2018-01-14                                          0
# ...                                               ...
# 2022-12-04                                          0
# 2022-12-11                                         21
# 2022-12-18                                          0
# 2022-12-25                                          1
# 2023-01-01                                          0
#
# Municipality                                  Cúcuta
#                             Category: All categories
# Week          violencia de genero: (North Santander)
# 2017-12-24                                       100
# 2017-12-31                                         0
# 2018-01-07                                         0
# 2018-01-14                                         0
# ...                                              ...
# 2022-12-04                                         0
# 2022-12-11                                         0
# 2022-12-18                                        17
# 2022-12-25                                        30
# 2023-01-01                                         1
#
# [264 rows x 10 columns]

# %%
# Remove the second level of the column index
merged_df.columns = merged_df.columns.droplevel(1)
merged_df.columns.name = None
merged_df = merged_df.iloc[1:,:]
merged_df = merged_df.reset_index().rename(columns={'index':'date'})
merged_df = merged_df[merged_df['date'] != 'Week']
merged_df
# Out:
#            date Medellín Cali Soacha Villavicencio Pasto Barranquilla  \
# 0    2017-12-24        0    0      0             1    30            0
# 1    2017-12-31       32    0     31             0    88           37
# 2    2018-01-07        0    1      2             0     0            0
# 3    2018-01-14       22   13     25             0     1            0
# 4    2018-01-21        2   19      0             0     0            1
# ..          ...      ...  ...    ...           ...   ...          ...
# 258  2022-12-04       41   13      0            17    50            0
# 259  2022-12-11        1   33     22             0     1           18
# 260  2022-12-18       38    0     22            12     1           19
# 261  2022-12-25       21   12     14            <1     0            0
# 262  2023-01-01        0   <1      1             0     0           20
#
#     Bucaramanga Ibagué Popayán Cúcuta
# 0            47      0       1    100
# 1             0      1       0      0
# 2             0      0       3      0
# 3            36      1       0      0
# 4             0      3      33     63
# ..          ...    ...     ...    ...
# 258           0     18       0      0
# 259          44     61      21      0
# 260           0     35       0     17
# 261          19     55       1     30
# 262           0     20       0      1
#
# [263 rows x 11 columns]

# %% [markdown]
# ### Get Epiweek

# %%
merged_df['date'] = pd.to_datetime(merged_df['date'])

# %%
merged_df['epiweek'] = merged_df['date'].apply(lambda x: Week.fromdate(x))

# replace <1 with 0
merged_df = merged_df.replace('<1', 0)

# %%
merged_df
# Out:
#           date Medellín Cali Soacha Villavicencio Pasto Barranquilla  \
# 0   2017-12-24        0    0      0             1    30            0
# 1   2017-12-31       32    0     31             0    88           37
# 2   2018-01-07        0    1      2             0     0            0
# 3   2018-01-14       22   13     25             0     1            0
# 4   2018-01-21        2   19      0             0     0            1
# ..         ...      ...  ...    ...           ...   ...          ...
# 258 2022-12-04       41   13      0            17    50            0
# 259 2022-12-11        1   33     22             0     1           18
# 260 2022-12-18       38    0     22            12     1           19
# 261 2022-12-25       21   12     14             0     0            0
# 262 2023-01-01        0    0      1             0     0           20
#
#     Bucaramanga Ibagué Popayán Cúcuta epiweek
# 0            47      0       1    100  201752
# 1             0      1       0      0  201801
# 2             0      0       3      0  201802
# 3            36      1       0      0  201803
# 4             0      3      33     63  201804
# ..          ...    ...     ...    ...     ...
# 258           0     18       0      0  202249
# 259          44     61      21      0  202250
# 260           0     35       0     17  202251
# 261          19     55       1     30  202252
# 262           0     20       0      1  202301
#
# [263 rows x 12 columns]

# %% [markdown]
# ### Save

# %%
merged_df.to_csv(f'{KEYWORD}.csv', index=False)
