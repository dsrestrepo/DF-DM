# %%
import pandas as pd
import numpy as np
import epiweeks
import os

# %% [markdown]
# ### Get Metadata and Labels

# %%
violence_sdoh = pd.read_csv('Metadata/Metadata.csv')
violence_sdoh
# Out:
#       Municipality code    Municipality  Population2007  Population2008  \
# 0                  5001        Medellín         2286126         2309689
# 1                  5002       Abejorral           20643           20944
# 2                  5004        Abriaquí            2261            2290
# 3                  5021      Alejandría            3935            4020
# 4                  5030           Amagá           27996           28331
# ...                 ...             ...             ...             ...
# 1096              97666         Taraira             432             540
# 1097              99001  Puerto Carreño           13742           14559
# 1098              99524    La Primavera            5190            5784
# 1099              99624   Santa Rosalía            3167            3378
# 1100              99773        Cumaribo           24342           26882
#
#       Population2009  Population2010  Population2011  Population2012  \
# 0            2331389         2353410         2379920         2410046
# 1              21197           21355           20973           20067
# 2               2321            2353            2386            2424
# 3               4096            4171            4244            4337
# 4              28624           28839           28776           28371
# ...              ...             ...             ...             ...
# 1096             689             891            1148            1355
# 1097           15346           16124           16934           17773
# 1098            6365            6920            7496            8034
# 1099            3586            3846            4067            4325
# 1100           29648           32594           35746           39128
#
#       Population2013  Population2014  ...  202322  202323  202324  202325  \
# 0            2428850         2436071  ...     171     150     148     162
# 1              19732           19796  ...       2       1       0       0
# 2               2471            2488  ...       0       0       0       0
# 3               4419            4467  ...       0       0       0       0
# 4              28259           28432  ...       1       1       3       1
# ...              ...             ...  ...     ...     ...     ...     ...
# 1096            1492            1612  ...       0       0       1       0
# 1097           18635           19519  ...       0       0       0       0
# 1098            8617            9166  ...       0       0       0       0
# 1099            4535            4635  ...       0       0       0       0
# 1100           42784           46893  ...       0       0       0       0
#
#       202326  202327  202328  202329  202330  202331
# 0        140     137     148     145     119      45
# 1          1       0       0       4       0       0
# 2          0       0       0       0       0       0
# 3          0       0       0       0       0       0
# 4          1       1       3       2       0       0
# ...      ...     ...     ...     ...     ...     ...
# 1096       0       0       0       1       0       0
# 1097       3       1       1       1       1       1
# 1098       0       0       1       0       0       0
# 1099       0       0       0       0       0       0
# 1100       0       0       0       0       0       0
#
# [1101 rows x 768 columns]

# %%
violence_sdoh.to_csv('metadata_labels.csv', index=False)

# %% [markdown]
# ### Get Internet data

# %% [markdown]
# #### Google Trends

# %%
def transform_dataframe(df, column_name):
    melted_df = pd.melt(df, id_vars=['epiweek'], var_name='Municipality Code', value_name=column_name)
    return melted_df[['Municipality Code', 'epiweek', column_name]]

# %%
def get_and_merge(path, dfs):
    
    for i, column_name in enumerate(dfs):
        if i == 0:
            df = pd.read_csv(path + column_name + '.csv')
            df.drop(columns=['date'], inplace=True)
            df = transform_dataframe(df, column_name)
        else:
            temp = pd.read_csv(path + column_name + '.csv')
            temp.drop(columns=['date'], inplace=True)
            temp = transform_dataframe(temp, column_name)
            df = df.merge(temp, on=['Municipality Code', 'epiweek'])
    return df

# %%
google_df = get_and_merge(path='Internet/Google/', dfs=['Violencia', 'violencia de genero'])
google_df
# Out:
#      Municipality Code  epiweek  Violencia  violencia de genero
# 0             Medellín   201752         16                    0
# 1             Medellín   201801         20                   32
# 2             Medellín   201802         14                    0
# 3             Medellín   201803         31                   22
# 4             Medellín   201804         31                    2
# ...                ...      ...        ...                  ...
# 2625            Cúcuta   202249          9                    0
# 2626            Cúcuta   202250         28                    0
# 2627            Cúcuta   202251         18                   17
# 2628            Cúcuta   202252         11                   30
# 2629            Cúcuta   202301         11                    1
#
# [2630 rows x 4 columns]

# %%
google_df.to_csv('google_data.csv', index=False)

# %% [markdown]
# #### Media Cloud

# %%
media_cloud = pd.read_csv('Internet/Media Cloud/labels.csv')
media_cloud
# Out:
#      Municipality code         publish_date  \
# 0             Popayán  2018-01-03 15:51:29
# 1             Popayán  2018-01-04 08:24:23
# 2             Popayán  2018-01-04 11:47:04
# 3             Popayán  2018-01-04 11:47:04
# 4             Popayán  2018-01-05 07:10:27
# ...                ...                  ...
# 7045             Pasto  2023-11-18 18:55:06
# 7046             Pasto  2023-11-18 22:04:00
# 7047             Pasto  2023-11-19 14:55:50
# 7048             Pasto  2023-11-19 16:09:03
# 7049             Pasto  2023-11-19 18:32:41
#
#                                                   title
# 0     Dos capturados en Cartagena por violencia intr...
# 1     Hallan cadáver de Yuly Tatiana Sánchez en caño...
# 2     Programa de Familias Fuertes cerró el 2017 con...
# 3     Programa de Familias Fuertes cerró el 2017 con...
# 4     Inspección de Ejército investiga incidente ent...
# ...                                                 ...
# 7045               Otro intento de violación en Kennedy
# 7046  Las declaraciones de Mancuso sobre Uribe en re...
# 7047         Garantía de seguridad mediante patrullajes
# 7048  Entre lágrimas celebró una leyenda del fútbol ...
# 7049  Itagüi, Antioquia: Identifican a las mujeres h...
#
# [7050 rows x 3 columns]

# %%
media_cloud['publish_date'] = media_cloud['publish_date'].apply(lambda x: x[:10])
media_cloud['publish_date'] = pd.to_datetime(media_cloud['publish_date'])
media_cloud['epiweek'] = media_cloud['publish_date'].apply(lambda x: epiweeks.Week.fromdate(x))

# Group by 'Municipality code' and 'epiweek', join titles, and add a count column
media_cloud = media_cloud.groupby(['Municipality code', 'epiweek'])['title'].apply(lambda x: '; '.join(x)).reset_index()
media_cloud['Count'] = media_cloud.groupby(['Municipality code', 'epiweek'])['title'].transform('count')

media_cloud
# Out:
#     Municipality code epiweek  \
# 0        Barranquilla  201847
# 1        Barranquilla  201849
# 2        Barranquilla  201852
# 3        Barranquilla  201903
# 4        Barranquilla  201904
# ..                ...     ...
# 966          Popayán  202343
# 967          Popayán  202344
# 968          Popayán  202345
# 969          Popayán  202346
# 970          Popayán  202347
#
#                                                  title  Count
# 0    Procuraduría se opone a que Maza Márquez vaya ...      1
# 1    Una mujer fallece en ataque a migrantes centro...      1
# 2    Duque emplaza a ‘el Paisa’ para que comparezca...      1
# 3    Más de 11 mil personas se han sometido a la JE...      1
# 4       OEA no logra consenso ante crisis de Venezuela      1
# ..                                                 ...    ...
# 966  La última guerra del mundo; Procuraduría alert...      1
# 967  Carlos F Galán, el hijo del fallecido Luis Car...      1
# 968  EL EJÉRCITO DE ISRAEL HA MATADO YA A MÁS DE 90...      1
# 969  El ángel de los cuchillos: una macabra escultu...      1
# 970  Sin golpes; NORMALIZANDO LAS RELACIONES CON SI...      1
#
# [971 rows x 4 columns]

# %% [markdown]
# #### GDELT

# %%
gdelt = pd.read_csv('Internet/gdelt/labels_violence_cohort.csv')
gdelt
# Out:
#       Municipality code   SQLDATE    Actor1Name Actor2Name  NumMentions  \
# 0         Villavicencio  20180903          FARC        NaN            5
# 1         Villavicencio  20180903      CIVILIAN        NaN            3
# 2         Villavicencio  20180903           NaN       FARC            5
# 3         Villavicencio  20180402      COLOMBIA        NaN            8
# 4         Villavicencio  20180403  RIGHTS GROUP        NaN           10
# ...                 ...       ...           ...        ...          ...
# 10697            Cúcuta  20201118      COLOMBIA        NaN           12
# 10698            Cúcuta  20201118     COLOMBIAN        NaN           25
# 10699            Cúcuta  20201118     PRESIDENT        NaN            3
# 10700            Cúcuta  20210102       CARRIER        NaN            5
# 10701            Cúcuta  20201118    INDIGENOUS     PANAMA            6
#
#        NumSources  NumArticles   AvgTone  \
# 0               1            5 -9.230769
# 1               1            3 -9.230769
# 2               1            5 -9.230769
# 3               1            8 -4.643963
# 4               1           10 -4.713805
# ...           ...          ...       ...
# 10697           5           12 -5.888438
# 10698           6           25 -5.701540
# 10699           1            3 -4.580153
# 10700           1            5 -1.003344
# 10701           2            6 -6.432749
#
#                                                SOURCEURL  \
# 0      https://morningstaronline.co.uk/article/colomb...
# 1      https://morningstaronline.co.uk/article/colomb...
# 2      https://morningstaronline.co.uk/article/colomb...
# 3      https://www.telesurtv.net/english/news/One-Mor...
# 4      https://www.aljazeera.com/news/2018/03/rights-...
# ...                                                  ...
# 10697  https://www.pressherald.com/2020/11/17/hurrica...
# 10698  https://www.pressherald.com/2020/11/17/hurrica...
# 10699  https://colombiareports.com/colombia-rescues-d...
# 10700  https://www.flightglobal.com/safety/avianca-a3...
# 10701  https://tucson.com/news/world/hurricane-iota-b...
#
#                                            ExtractedText  \
# 0       Reset on:  COLOMBIA brought charges against b...
# 1       Reset on:  COLOMBIA brought charges against b...
# 2       Reset on:  COLOMBIA brought charges against b...
# 3      teleSURHD Opacity  If there is not a Board of ...
# 4      The Colombian social leader, known as an ‘unti...
# ...                                                  ...
# 10697  \n\n\n\nSign in or Subscribe \nSee Offers\n\n\...
# 10698  \n\n\n\nSign in or Subscribe \nSee Offers\n\n\...
# 10699  Colombia’s air force rescued more than 50 peop...
# 10700                                                NaN
# 10701                                                NaN
#
#                                             ContentTitle
# 0                                       LATEST EDITORIAL
# 1                                       LATEST EDITORIAL
# 2                                       LATEST EDITORIAL
# 3      Guatemala: Tensions and Delay in the Formation...
# 4                                             Skip links
# ...                                                  ...
# 10697                                           Sign In:
# 10698                                           Sign In:
# 10699  Colombia rescues dozens from island destroyed ...
# 10700                                                NaN
# 10701                                                NaN
#
# [10702 rows x 11 columns]

# %%
# Convert SQLDATE to empiweek in the yearweek format
gdelt['epiweek'] = gdelt['SQLDATE'].apply(lambda x: epiweeks.Week.fromdate(pd.to_datetime(str(x), format='%Y%m%d')))
gdelt = gdelt[['Municipality code', 'epiweek', 'Actor1Name', 'NumMentions', 
               'NumSources', 'NumArticles', 'AvgTone', 'ExtractedText']]

# Group by epiweek and Municipality code and perform aggregations
gdelt_preproc = gdelt.groupby(['epiweek', 'Municipality code']).agg({
    'Actor1Name': lambda x: ', '.join(x.dropna()) if x.notna().any() else None,
    'NumMentions': 'sum',
    'NumSources': 'sum',
    'NumArticles': 'sum',
    'AvgTone': 'mean',
    'ExtractedText': lambda x: '; '.join(x.dropna()) if x.notna().any() else None,
}).reset_index()

# Create a counter for the number of posts per epiweek
gdelt_preproc['PostCount'] = gdelt.groupby(['epiweek', 'Municipality code']).size().reset_index(name='PostCount')['PostCount']
gdelt_preproc
# Out:
#      epiweek Municipality code  \
# 0     201801              Cali
# 1     201801          Medellín
# 2     201801             Pasto
# 3     201801           Popayán
# 4     201801            Soacha
# ...      ...               ...
# 1347  202250            Soacha
# 1348  202251      Barranquilla
# 1349  202251          Medellín
# 1350  202251             Pasto
# 1351  202251            Soacha
#
#                                              Actor1Name  NumMentions  \
# 0                                                  FARC           10
# 1     COLOMBIA, COLOMBIA, GOVERNMENT, COLOMBIA, COLO...           82
# 2                            POLICE, COLOMBIA, COLOMBIA           25
# 3     GUNMEN, POLICE, COLOMBIA, COLOMBIA, GUNMEN, GU...           19
# 4     COMMUNITY, BOGOTA, COLOMBIAN, COLOMBIAN, COLOM...           71
# ...                                                 ...          ...
# 1347                                             BOGOTA           10
# 1348                               TANKER, BARRANQUILLA           20
# 1349                                               None            4
# 1350                               COLOMBIAN, COLOMBIAN           30
# 1351    AMERICAN, BUSINESS, BUSINESS, CROATIA, COLOMBIA           23
#
#       NumSources  NumArticles   AvgTone  \
# 0              1           10 -4.921260
# 1             15           66 -6.511003
# 2              5           25 -3.281993
# 3              6           19 -5.982906
# 4             12           71 -9.385465
# ...          ...          ...       ...
# 1347           1           10 -4.054054
# 1348           2           20 -5.161290
# 1349           1            4 -4.334365
# 1350           2           30 -9.833024
# 1351           6           23 -2.542912
#
#                                           ExtractedText  PostCount
# 0                                                  None          1
# 1     An attack on a nightclub in an important cocai...         14
# 2     The ELN is the only guerrilla group still at w...          5
# 3                                                  None          6
# 4                                                  None         12
# ...                                                 ...        ...
# 1347  CHARLOTTE, N.C. (QUEEN CITY NEWS) – The Foo Fi...          1
# 1348  Barranquilla, Colombia, Dec 21 (EFE).- A firef...          2
# 1349  We have gotten word of a horrifying story unfo...          1
# 1350  Police offices in Colombia are documenting “ex...          2
# 1351  Truce will last from Saturday to January 2, le...          6
#
# [1352 rows x 9 columns]

# %% [markdown]
# #### Merge gdelt and media cloud data

# %%
# Merge the two DataFrames on 'epiweek' and 'Municipality code'
merged_df = pd.merge(gdelt_preproc, media_cloud, on=['epiweek', 'Municipality code'], how='outer')

# Fill NaN values in Count with 0
merged_df['Count'].fillna(0, inplace=True)
merged_df['PostCount'].fillna(0, inplace=True)
merged_df['Count'] = merged_df['Count'] + merged_df['PostCount']
merged_df.drop(columns=['PostCount'], inplace=True)

# Concatenate 'title' and 'Actor1Name' columns
merged_df['title'] = merged_df['Actor1Name'].fillna('') + ';' + merged_df['title'].fillna('')
# Drop the 'Actor1Name' column
merged_df.drop(columns=['Actor1Name'], inplace=True)

# Concatenate 'title' and 'ExtractedText' columns
#merged_df['title'] = merged_df['title'].fillna('') + ';' + merged_df['ExtractedText'].fillna('')
# Drop the 'ExtractedText' column
merged_df.drop(columns=['ExtractedText'], inplace=True)

# Group by 'epiweek' and 'Municipality code' and perform aggregation
media_df = merged_df.groupby(['Municipality code', 'epiweek']).agg({
    'Count': 'sum',
    'title': lambda x: ';'.join(x),
    'NumMentions': 'sum',
    'NumSources': 'sum',
    'NumArticles': 'sum',
    'AvgTone': 'mean',
}).reset_index()

media_df
# Out:
#      Municipality code epiweek  Count  \
# 0         Barranquilla  201803    5.0
# 1         Barranquilla  201804    8.0
# 2         Barranquilla  201805   51.0
# 3         Barranquilla  201806    2.0
# 4         Barranquilla  201807    6.0
# ...                ...     ...    ...
# 2153     Villavicencio  202128    4.0
# 2154     Villavicencio  202131    1.0
# 2155     Villavicencio  202137    3.0
# 2156     Villavicencio  202140    2.0
# 2157     Villavicencio  202214    3.0
#
#                                                   title  NumMentions  \
# 0     POLICE, COLOMBIA, PROSECUTOR, COLOMBIA, PROSEC...         27.0
# 1     BARRANQUILLA, COLOMBIA, BARRANQUILLA, NEWSPAPE...        127.0
# 2     POLICE, POLICE OFFICER, POLICE OFFICER, ASSAIL...       2444.0
# 3                               BARRANQUILLA, COLOMBIA;         15.0
# 4     GUERRILLA, FARC, GOVERNMENT FORCES, COLOMBIAN,...         44.0
# ...                                                 ...          ...
# 2153                  COLOMBIA, POLICE, POLICE, POLICE;          7.0
# 2154                                                  ;          6.0
# 2155               NATIONAL POLICE, COLOMBIA, CRIMINAL;         18.0
# 2156                                COLOMBIA, CRIMINAL;          6.0
# 2157                              COMMUNITY, ARMED MEN;         10.0
#
#       NumSources  NumArticles   AvgTone
# 0            5.0         27.0 -7.142799
# 1           15.0        127.0 -7.153317
# 2          277.0       2166.0 -6.787119
# 3            2.0         15.0 -4.870645
# 4            6.0         44.0 -4.532365
# ...          ...          ...       ...
# 2153         4.0          7.0 -5.732946
# 2154         1.0          6.0 -5.121294
# 2155         3.0         18.0 -7.229890
# 2156         2.0          6.0 -3.164557
# 2157         3.0         10.0 -3.597122
#
# [2158 rows x 8 columns]

# %%
media_df.to_csv('media_data.csv', index=False)

# %% [markdown]
# ### Merge Google and News data

# %%
news = pd.read_csv('media_data.csv')
news
# Out:
#      Municipality code  epiweek  Count  \
# 0         Barranquilla   201803    5.0
# 1         Barranquilla   201804    8.0
# 2         Barranquilla   201805   51.0
# 3         Barranquilla   201806    2.0
# 4         Barranquilla   201807    6.0
# ...                ...      ...    ...
# 2153     Villavicencio   202128    4.0
# 2154     Villavicencio   202131    1.0
# 2155     Villavicencio   202137    3.0
# 2156     Villavicencio   202140    2.0
# 2157     Villavicencio   202214    3.0
#
#                                                   title  NumMentions  \
# 0     POLICE, COLOMBIA, PROSECUTOR, COLOMBIA, PROSEC...         27.0
# 1     BARRANQUILLA, COLOMBIA, BARRANQUILLA, NEWSPAPE...        127.0
# 2     POLICE, POLICE OFFICER, POLICE OFFICER, ASSAIL...       2444.0
# 3                               BARRANQUILLA, COLOMBIA;         15.0
# 4     GUERRILLA, FARC, GOVERNMENT FORCES, COLOMBIAN,...         44.0
# ...                                                 ...          ...
# 2153                  COLOMBIA, POLICE, POLICE, POLICE;          7.0
# 2154                                                  ;          6.0
# 2155               NATIONAL POLICE, COLOMBIA, CRIMINAL;         18.0
# 2156                                COLOMBIA, CRIMINAL;          6.0
# 2157                              COMMUNITY, ARMED MEN;         10.0
#
#       NumSources  NumArticles   AvgTone
# 0            5.0         27.0 -7.142799
# 1           15.0        127.0 -7.153317
# 2          277.0       2166.0 -6.787119
# 3            2.0         15.0 -4.870645
# 4            6.0         44.0 -4.532365
# ...          ...          ...       ...
# 2153         4.0          7.0 -5.732946
# 2154         1.0          6.0 -5.121294
# 2155         3.0         18.0 -7.229890
# 2156         2.0          6.0 -3.164557
# 2157         3.0         10.0 -3.597122
#
# [2158 rows x 8 columns]

# %%
google = pd.read_csv('google_data.csv')
google
# Out:
#      Municipality Code  epiweek  Violencia  violencia de genero
# 0             Medellín   201752         16                    0
# 1             Medellín   201801         20                   32
# 2             Medellín   201802         14                    0
# 3             Medellín   201803         31                   22
# 4             Medellín   201804         31                    2
# ...                ...      ...        ...                  ...
# 2625            Cúcuta   202249          9                    0
# 2626            Cúcuta   202250         28                    0
# 2627            Cúcuta   202251         18                   17
# 2628            Cúcuta   202252         11                   30
# 2629            Cúcuta   202301         11                    1
#
# [2630 rows x 4 columns]

# %%
internet = pd.merge(google, news, right_on=['Municipality code', 'epiweek'], left_on=['Municipality Code', 'epiweek'], how='left')
internet.drop(columns=['title', 'Municipality Code'], inplace=True)
# drom nan in Municipality code
internet.dropna(subset=['Municipality code'], inplace=True)
internet.fillna(0, inplace=True)
internet
# Out:
#       epiweek  Violencia  violencia de genero Municipality code  Count  \
# 1      201801         20                   32          Medellín   14.0
# 2      201802         14                    0          Medellín    7.0
# 3      201803         31                   22          Medellín   20.0
# 4      201804         31                    2          Medellín    6.0
# 5      201805         38                    0          Medellín   13.0
# ...       ...        ...                  ...               ...    ...
# 2618   202242         58                    0            Cúcuta    2.0
# 2619   202243         67                    1            Cúcuta    4.0
# 2620   202244         29                   19            Cúcuta    2.0
# 2625   202249          9                    0            Cúcuta    2.0
# 2626   202250         28                    0            Cúcuta    1.0
#
#       NumMentions  NumSources  NumArticles   AvgTone
# 1            82.0        15.0         66.0 -6.511003
# 2            38.0         7.0         38.0 -1.518428
# 3           107.0        20.0        107.0 -3.412981
# 4            37.0         6.0         37.0 -4.515344
# 5            50.0        13.0         50.0 -5.697037
# ...           ...         ...          ...       ...
# 2618         20.0         2.0         20.0 -3.795380
# 2619         26.0         4.0         26.0 -4.112392
# 2620         10.0         2.0         10.0 -5.146430
# 2625          5.0         2.0          5.0 -6.451613
# 2626          3.0         1.0          3.0 -5.195271
#
# [1567 rows x 9 columns]

# %%
internet.to_csv('internet_data.csv', index=False)
